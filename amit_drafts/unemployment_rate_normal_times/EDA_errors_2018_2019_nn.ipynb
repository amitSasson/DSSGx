# %%
import os
import mlflow
import numpy as np
import pandas as pd

from math import sqrt
from joblib import delayed
from joblib import Parallel

from warnings import catch_warnings
from warnings import filterwarnings
from multiprocessing import cpu_count
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.statespace.sarimax import SARIMAX

import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from matplotlib import pyplot
import matplotlib.dates as mdates

from pathlib import Path
from functools import reduce
from datetime import datetime

from prophet import Prophet

import random
from scipy.stats import ttest_ind
import statsmodels.api as sm
from statsmodels.formula.api import ols
from sklearn.linear_model import LinearRegression, RidgeCV, Ridge
from regressors import stats
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-bcd6018f1d81> in <module>
#      30 from statsmodels.formula.api import ols
#      31 from sklearn.linear_model import LinearRegression, RidgeCV, Ridge
# ---> 32 from sklearn import MinMaxScaler
#      33 from regressors import stats
#      34 from mlxtend.feature_selection import SequentialFeatureSelector as sfs
#
# ImportError: cannot import name 'MinMaxScaler' from 'sklearn' (/Users/amitsasson/venv/DSSGx/lib/python3.8/site-packages/sklearn/__init__.py)

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv('./../../error_dfs/error_2018_2019_nn.csv', converters={'ags2': str, 'ags5': str} )

# %%
# fix ags5 missing 0 
df['ags5'] = np.where(df.ags5.str.len() ==4, '0' + df['ags5'], df['ags5'])

# %%
# add 'ags2','bundesland','kreis'
df2 = pd.read_csv('./../../corona_data_sets/oeffentliche_finanzen.csv', converters={'ags2': str, 'ags5': str} )
df = pd.merge(df, df2[['ags2','ags5','bundesland','kreis']])
df['date'] = pd.to_datetime(df['date'], format = '%Y-%m-%d')
df
# Out:
#        ags5       date  ground_truth      pred     error ags2  \
# 0     01001 2018-01-31           9.3  8.666405  0.633595   01
# 1     01001 2018-02-28           9.2  8.807995  0.392005   01
# 2     01001 2018-03-31           9.1  8.730574  0.369426   01
# 3     01001 2018-04-30           8.8  8.242456  0.557545   01
# 4     01001 2018-05-31           8.3  8.107006  0.192994   01
# ...     ...        ...           ...       ...       ...  ...
# 9619  16077 2019-08-31           7.0  7.114399  0.114399   16
# 9620  16077 2019-09-30           6.5  7.089566  0.589566   16
# 9621  16077 2019-10-31           6.5  6.721840  0.221840   16
# 9622  16077 2019-11-30           6.3  6.756373  0.456373   16
# 9623  16077 2019-12-31           6.5  7.001636  0.501636   16
#
#               bundesland             kreis
# 0     Schleswig-Holstein  Flensburg, Stadt
# 1     Schleswig-Holstein  Flensburg, Stadt
# 2     Schleswig-Holstein  Flensburg, Stadt
# 3     Schleswig-Holstein  Flensburg, Stadt
# 4     Schleswig-Holstein  Flensburg, Stadt
# ...                  ...               ...
# 9619           Thüringen  Altenburger Land
# 9620           Thüringen  Altenburger Land
# 9621           Thüringen  Altenburger Land
# 9622           Thüringen  Altenburger Land
# 9623           Thüringen  Altenburger Land
#
# [9624 rows x 8 columns]

# %%
df['date'] = pd.to_datetime(df['date'], format = '%Y-%m-%d')

# %% [markdown]
# ## Plot each variable

# %%
g = sns.lineplot(data=df, x="date", y="pred",  hue="ags5")
g.xaxis.set_major_locator(mdates.MonthLocator(interval=6))
g.legend_.remove()

# %%
g = sns.lineplot(data=df, x="date", y="error",  hue="ags5")
g.xaxis.set_major_locator(mdates.MonthLocator(interval=6))
g.legend_.remove()

# %%
g = sns.lineplot(data=df, x="date", y="ground_truth",  hue="ags5")
g.xaxis.set_major_locator(mdates.MonthLocator(interval=6))
g.legend_.remove()

# %%
g = sns.scatterplot(data=df, x="pred", y="error",  hue="ags5")
g.legend_.remove()

# %% [markdown]
# ## Plot sample to compare prediction to ground truth

# %%
df_long = df.melt(id_vars=['date','ags5','ags2','bundesland','kreis'], var_name='y_type', value_name='vals')

# %%
df_long = df_long[df_long['y_type'].isin(['ground_truth','pred'])]

# %%
sample_args = random.sample(list(set(df_long['ags5'])), 30)
df_sample = df_long[df_long['ags5'].isin(sample_args)]

# %%
g = sns.lineplot(data=df_sample, x="date", y="vals",  hue="ags5", style="y_type")
g.xaxis.set_major_locator(mdates.MonthLocator(interval=6))
g.legend_.remove()

# %% [markdown]
# ## Look into mean errors

# %%
df_mean_error = df.groupby(['ags5','ags2','bundesland','kreis']).mean()
df_mean_error
# Out:
#                                                       ground_truth      pred  \
# ags5  ags2 bundesland         kreis
# 01001 01   Schleswig-Holstein Flensburg, Stadt            8.137500  7.654453
# 01002 01   Schleswig-Holstein Kiel, Landeshauptstadt      7.883333  8.146062
# 01003 01   Schleswig-Holstein Lübeck, Hansestadt          7.525000  7.730177
# 01004 01   Schleswig-Holstein Neumünster, Stadt           8.125000  8.292714
# 01051 01   Schleswig-Holstein Dithmarschen                5.887500  6.134025
# ...                                                            ...       ...
# 16073 16   Thüringen          Saalfeld-Rudolstadt         5.375000  5.428801
# 16074 16   Thüringen          Saale-Holzland-Kreis        4.329167  4.451131
# 16075 16   Thüringen          Saale-Orla-Kreis            4.733333  4.771823
# 16076 16   Thüringen          Greiz                       4.791667  4.931115
# 16077 16   Thüringen          Altenburger Land            7.391667  7.654453
#
#                                                          error
# ags5  ags2 bundesland         kreis
# 01001 01   Schleswig-Holstein Flensburg, Stadt        0.514029
# 01002 01   Schleswig-Holstein Kiel, Landeshauptstadt  0.290269
# 01003 01   Schleswig-Holstein Lübeck, Hansestadt      0.235069
# 01004 01   Schleswig-Holstein Neumünster, Stadt       0.222192
# 01051 01   Schleswig-Holstein Dithmarschen            0.393344
# ...                                                        ...
# 16073 16   Thüringen          Saalfeld-Rudolstadt     0.160927
# 16074 16   Thüringen          Saale-Holzland-Kreis    0.149345
# 16075 16   Thüringen          Saale-Orla-Kreis        0.176683
# 16076 16   Thüringen          Greiz                   0.226252
# 16077 16   Thüringen          Altenburger Land        0.310309
#
# [401 rows x 3 columns]

# %%
g = sns.scatterplot(data=df_mean_error, x="ground_truth", y="error",  hue="ags5")
g.legend_.remove()

# %%
g = sns.scatterplot(data=df_mean_error, x="pred", y="error",  hue="ags5")
g.legend_.remove()

# %%
df_mean_error.sort_values(by = ['error'], ascending=False)
# Out:
#                                                      ground_truth      pred  \
# ags5  ags2 bundesland             kreis
# 13073 13   Mecklenburg-Vorpommern Vorpommern-Rügen       8.616667  9.080248
# 03462 03   Niedersachsen          Wittmund               5.487500  5.750702
# 05914 05   Nordrhein-Westfalen    Hagen                  9.666667  9.456875
# 07320 07   Rheinland-Pfalz        Stadt Zweibrücken      5.741667  5.861919
# 09276 09   Freistaat Bayern       Regen                  3.154167  3.355386
# ...                                                           ...       ...
# 05366 05   Nordrhein-Westfalen    Euskirchen             5.008333  5.039858
# 06432 06   Hessen                 Darmstadt-Dieburg      4.387500  4.381284
# 09175 09   Freistaat Bayern       Ebersberg              1.862500  1.821620
# 06631 06   Hessen                 Fulda                  2.741667  2.704146
# 09562 09   Freistaat Bayern       Erlangen               3.616667  3.619546
#
#                                                         error
# ags5  ags2 bundesland             kreis
# 13073 13   Mecklenburg-Vorpommern Vorpommern-Rügen   0.638194
# 03462 03   Niedersachsen          Wittmund           0.589225
# 05914 05   Nordrhein-Westfalen    Hagen              0.565753
# 07320 07   Rheinland-Pfalz        Stadt Zweibrücken  0.542494
# 09276 09   Freistaat Bayern       Regen              0.519725
# ...                                                       ...
# 05366 05   Nordrhein-Westfalen    Euskirchen         0.076856
# 06432 06   Hessen                 Darmstadt-Dieburg  0.076734
# 09175 09   Freistaat Bayern       Ebersberg          0.070578
# 06631 06   Hessen                 Fulda              0.065489
# 09562 09   Freistaat Bayern       Erlangen           0.060287
#
# [401 rows x 3 columns]

# %%
sns.kdeplot(data=df_mean_error, x="error", common_norm=False)
# Out:
# <AxesSubplot:xlabel='error', ylabel='Density'>

# %% [markdown]
# ## Look into errors

# %%
df.sort_values(by = ['error'], ascending=False)
# Out:
#        ags5       date  ground_truth      pred     error ags2  \
# 8345  13073 2019-06-30           7.0  8.599673  1.599673   13
# 1445  03462 2018-06-30           4.4  5.929067  1.529067   03
# 8344  13073 2019-05-31           7.3  8.733983  1.433983   13
# 21    01001 2019-10-31           8.1  6.721840  1.378160   01
# 8343  13073 2019-04-30           7.9  9.253987  1.353987   13
# ...     ...        ...           ...       ...       ...  ...
# 4420  08121 2018-05-31           4.9  4.900155  0.000155   08
# 5056  08335 2019-05-31           2.9  2.899908  0.000092   08
# 5730  09184 2019-07-31           2.2  2.200044  0.000044   09
# 3566  07137 2019-03-31           3.4  3.400010  0.000010   07
# 7611  09780 2018-04-30           2.6  2.600005  0.000005   09
#
#                   bundesland             kreis
# 8345  Mecklenburg-Vorpommern  Vorpommern-Rügen
# 1445           Niedersachsen          Wittmund
# 8344  Mecklenburg-Vorpommern  Vorpommern-Rügen
# 21        Schleswig-Holstein  Flensburg, Stadt
# 8343  Mecklenburg-Vorpommern  Vorpommern-Rügen
# ...                      ...               ...
# 4420       Baden-Württemberg         Heilbronn
# 5056       Baden-Württemberg          Konstanz
# 5730        Freistaat Bayern           München
# 3566         Rheinland-Pfalz     Mayen-Koblenz
# 7611        Freistaat Bayern        Oberallgäu
#
# [9624 rows x 8 columns]

# %%
df['diff_ground_truth'] = df.groupby('ags5')['ground_truth'].diff(1) 
df['diff_ground_truth_abs'] = df['diff_ground_truth'].abs()

# %%
g = sns.scatterplot(data=df, x="diff_ground_truth_abs", y="error",  hue="ags5")
g.legend_.remove()

# %%
sns.kdeplot(data=df, x="error", common_norm=False)
# Out:
# <AxesSubplot:xlabel='error', ylabel='Density'>

# %%
sns.kdeplot(data=df, x="error", common_norm=False,log_scale=True)
# Out:
# <AxesSubplot:xlabel='error', ylabel='Density'>

# %% [markdown]
# # Load structural data

# %%
df_structural = pd.read_csv('./../../final_dfs/for_modeling/df_final_stationery.csv', converters={'ags2': str, 'ags5': str} )

df_structural["urban_/_rural"] = np.where(df_structural["urban_/_rural"]==1, 'urban', 'rural')
df_structural['eligible_area'] = np.where(df_structural['eligible_area']==1, 'eligible_area', 'not_eligible_area')
df_structural['east_west'] = np.where(df_structural['east_west']==1, 'west', 'east')
df_structural = df_structural.rename(columns={'urban_/_rural': 'urban_rural'})
df_structural
# Out:
#      cluster                   kreis   ags5 ags2  supermarkets_population  \
# 0          0        Flensburg, Stadt  01001   01                       92
# 1          2  Kiel, Landeshauptstadt  01002   01                       92
# 2          2      Lübeck, Hansestadt  01003   01                       90
# 3          0       Neumünster, Stadt  01004   01                       85
# 4          0            Dithmarschen  01051   01                       51
# ..       ...                     ...    ...  ...                      ...
# 396        0     Saalfeld-Rudolstadt  16073   16                       62
# 397        0    Saale-Holzland-Kreis  16074   16                       54
# 398        0        Saale-Orla-Kreis  16075   16                       54
# 399        0                   Greiz  16076   16                       55
# 400        0        Altenburger Land  16077   16                       62
#
#      supermarkets_average_distance  public_transport_availability  \
# 0                              500                             35
# 1                              460                             37
# 2                              532                             37
# 3                              588                             37
# 4                             1864                             35
# ..                             ...                            ...
# 396                           1423                             37
# 397                           1677                             38
# 398                           1686                             35
# 399                           1654                             38
# 400                           1458                             35
#
#      average_distance_bus_stop  average_distance_train_station  \
# 0                          240                            2901
# 1                          268                            2037
# 2                          297                            1927
# 3                          316                            1648
# 4                          448                            3517
# ..                         ...                             ...
# 396                        341                            2492
# 397                        343                            3419
# 398                        449                            3172
# 399                        608                            2779
# 400                        584                            3628
#
#      average_distance_public_transport  ...  room_type_location  \
# 0                                  240  ...                   2
# 1                                  265  ...                   2
# 2                                  294  ...                   1
# 3                                  313  ...                   2
# 4                                  443  ...                   4
# ..                                 ...  ...                 ...
# 396                                322  ...                   3
# 397                                340  ...                   3
# 398                                444  ...                   3
# 399                                563  ...                   3
# 400                                574  ...                   3
#
#      district_settlement_structure  type_of_settlement_structure  urban_rural  \
# 0                                4                             3        rural
# 1                                1                             2        urban
# 2                                1                             2        urban
# 3                                3                             2        rural
# 4                                4                             3        rural
# ..                             ...                           ...          ...
# 396                              4                             2        rural
# 397                              3                             2        rural
# 398                              4                             2        rural
# 399                              2                             2        urban
# 400                              3                             2        rural
#
#      metropolitan_region  metropolitan_area  east_west  border_proximity  \
# 0                     99                 99       west                 1
# 1                     99                 99       west                 0
# 2                      5                 99       west                 0
# 3                      5                 99       west                 0
# 4                      5                 99       west                 0
# ..                   ...                ...        ...               ...
# 396                   99                 99       east                 0
# 397                   99                 99       east                 0
# 398                   99                 99       east                 2
# 399                   99                 99       east                 0
# 400                    7                 99       east                 0
#
#      support_area_status  eligible_area
# 0                      C  eligible_area
# 1                    C/D  eligible_area
# 2                    C/D  eligible_area
# 3                      D  eligible_area
# 4                      C  eligible_area
# ..                   ...            ...
# 396                   C*  eligible_area
# 397                   C*  eligible_area
# 398                   C*  eligible_area
# 399                   C*  eligible_area
# 400                   C*  eligible_area
#
# [401 rows x 179 columns]

# %% [markdown]
# ### Merge to df with mean errors

# %%
df_mixed = pd.merge(df_mean_error, df_structural, on = ['ags5','ags2'])
df_mixed['ags2'] = df_mixed['ags2'].astype('category')
list(df_mixed.columns)
# Out:
# ['ags5',
#  'ags2',
#  'ground_truth',
#  'pred',
#  'error',
#  'cluster',
#  'kreis',
#  'supermarkets_population',
#  'supermarkets_average_distance',
#  'public_transport_availability',
#  'average_distance_bus_stop',
#  'average_distance_train_station',
#  'average_distance_public_transport',
#  'Unnamed:_0',
#  'number_of_students',
#  'number_of_hospitals',
#  'number_of_hospital_beds',
#  'number_of_hospital_beds_adj',
#  'hospital_patiants',
#  'households_of_1_person',
#  'households_of_2_person',
#  'households_of_3_person',
#  'households_of_4_person',
#  'households_of_5_person_or_more',
#  'household_with_kids',
#  'household_with_kids_under_3',
#  'household_with_kids_over_3_under_6',
#  'household_with_kids_over_6_under_10',
#  'household_with_kids_over_10_under_15',
#  'household_with_kids_over_15_under_18',
#  'household_with_double_income_no_kids',
#  'car_density',
#  'no_of_paths_per_person_and_day',
#  'kilometers_per_person_and_day',
#  '_percentage_out_of_home',
#  'share_of_journeys_on_foot',
#  'share_of_journeys_on_bike',
#  'proportion_of_motorised_vehicle_passenger',
#  'share_of_motorised_vehicle_driver',
#  'share_of_public_transport_',
#  'public_transport_per_1000_inhabitants',
#  'activity_index',
#  'municipal_dept_per_capita',
#  'municipal_tax_per_capita',
#  'municipal_tax_per_capita.1',
#  'no_of_births_in_2018',
#  '2018_population',
#  '2019_population',
#  '2018_men_population',
#  '2018_women_population',
#  '2018_population_under_3_yrs',
#  '2018_population_3_to_6',
#  '2018_population_6_to_10',
#  '2018_population_10_to_15',
#  '2018_population_15_to_18',
#  '2018_population_18_to_20',
#  '2018_population_20_to_25',
#  '2018_population_25_to_30',
#  '2018_population_30_to_35',
#  '2018_population_35_to_40',
#  '2018_population_40_to_45',
#  '2018_population_45_to_50',
#  '2018_population_50_to_55',
#  '2018_population_55_to_60',
#  '2018_population_60_to_65',
#  '2018_population_65_to_75',
#  '2018_population_above_75',
#  '2019_population_under_5',
#  '2019_population_5_to_15',
#  '2019_population_15_to_35',
#  '2019_population_35_to_60',
#  '2019_population_60_to_80',
#  '2019_population_above_80',
#  'no_of_foreigners_2018',
#  'proportion_of_foreigners_in_2018',
#  'no_of_births_per_capita',
#  'Number_of_Commuters_place_of_work',
#  'Number_of_Commuters_on_place_of_residence)',
#  'Commuter_Balance',
#  'Proportion_of_in_commuters',
#  'Share_of_out_commuters',
#  'Relative_Commuter_Balance',
#  'Commute_within_50km',
#  'Commute_within_150km',
#  'Commute_within_300km',
#  'number_accomodation_establishments',
#  'number_of_beds',
#  'number_of_guests',
#  'guests_staying_overnight',
#  'number_of_companies',
#  'number_of_companies_agriculture',
#  'number_of_companies_mining',
#  'number_of_companies_manufacturing',
#  'number_of_companies_energy',
#  'number_of_companies_water_and_sewage',
#  'number_of_companies_construction',
#  'number_of_companies_repair_motor_vehicles',
#  'number_of_companies_transport',
#  'number_of_companies_hospitality',
#  'number_of_companies_communication',
#  'number_of_companies_financial_and_insurance',
#  'number_of_companies_real_estat',
#  'number_of_companies_technical_services',
#  'number_of_companies_economic_services',
#  'number_of_companies_administration',
#  'number_of_companies_education',
#  'number_of_companies_health_and_social_services',
#  'number_of_companies_arts_entertainment',
#  'number_of_companies_rendering_other_services',
#  'number_of_companies_domestic_staff',
#  'number_of_companies_extraterritorial',
#  'number_of_companies_1_to_4_employees',
#  'number_of_companies_5_to_49_employees',
#  'number_of_companies_50_to_400_employees',
#  'number_of_companies_500_or_more_employees',
#  'no_of_hairdressers',
#  'no_of_restraunts',
#  'no_of_branches',
#  'no_of_commertial_units',
#  'no_of_shopping_malls',
#  'no_of_clubs',
#  'no_of_slaughterhouse',
#  'no_of_education_centers',
#  'no_of_shopping',
#  'no_of_free_time',
#  'no_of_tourism_points',
#  'no_of_food_and_drink',
#  'no_of_public_institution',
#  'no_of_traffic_centers',
#  'no_of_health_centers',
#  'no_of_business',
#  'total_area',
#  'Residential_area_percentage',
#  'industrial_/_commertial_area_percentage',
#  'dump_area_percentage',
#  'mining_area_percentage',
#  'open_pit,_mine,_quarry_area_percentage',
#  'mixed_use_area_percentage',
#  'special_functional_character_land_percentage',
#  'sport,_leisure,_recreation_area_percentage',
#  'cemetry_area_percentage',
#  'road_area_percentage',
#  'space_area_percentage',
#  'rail_traffic_area_percentage',
#  'air_traffic_area_percentage',
#  'shipping_area_percentage',
#  'agri_area_percentage',
#  'forrest_area_percentage',
#  'wood_area_percentage',
#  'health_area_percentage',
#  'moor_area_percentage',
#  'swamp_area_percentage',
#  'without_vegetation_area_percentage',
#  'flowing_water_percentage',
#  'harbor_basin_percentage',
#  'standing_water_percentage',
#  'sea_percentage',
#  'median_income',
#  'purchasing_power_per_household',
#  'purchasing_power_per_person',
#  'debtor_quota',
#  'household_in_income_calss_1',
#  'household_in_income_calss_2',
#  'household_in_income_calss_3',
#  'household_in_income_calss_4',
#  'household_in_income_calss_5',
#  'household_in_income_calss_6',
#  'labor_market_region',
#  'growing_/_shrinking_circles',
#  'labor_market_type',
#  'grw_funding_framework',
#  'settlement_structure_type_of_labor_market_region',
#  'room_type_location',
#  'district_settlement_structure',
#  'type_of_settlement_structure',
#  'urban_rural',
#  'metropolitan_region',
#  'metropolitan_area',
#  'east_west',
#  'border_proximity',
#  'support_area_status',
#  'eligible_area']

# %% [markdown]
# ### Compare error in two_groups

# %%
#function to do that cor a spesific column 
def compare_error_in_two_groups(df, column_name): 
    p = sns.kdeplot(data=df, x="error", hue=column_name,  common_norm=False)
    p.set_title('Residuals')
    plt.savefig(f'{column_name}_resid.png')
    plt.show()
    df[column_name] = df[column_name].astype(str)
    one, two = list(set(df[column_name]))
    df_one = df[df[column_name]==one]
    df_two = df[df[column_name]==two]
    return ttest_ind(df_one['error'], df_two['error'], equal_var=False)

# %%
compare_error_in_two_groups(df_mixed, 'eligible_area')
# Out:
# Ttest_indResult(statistic=10.88453967583672, pvalue=6.6404363018331e-23)

# %%
compare_error_in_two_groups(df_mixed, 'east_west')
# Out:
# Ttest_indResult(statistic=6.157566993146951, pvalue=8.955862206180588e-09)

# %%
compare_error_in_two_groups(df_mixed, 'urban_rural')
# Out:
# Ttest_indResult(statistic=-4.074555326786926, pvalue=5.585027887494875e-05)

# %% [markdown]
# ### Compare compare error in multiple groups

# %%
#function to do that cor a spesific column 
def compare_error_in_two_groups(df, column_name): 
    sns.kdeplot(data=df, x="error", hue=column_name,  common_norm=False)
    plt.show()
    mod = ols(f'error ~ {column_name}',
                data=df).fit()
                
    aov_table = sm.stats.anova_lm(mod, typ=2)
    print(aov_table)

# %%
compare_error_in_two_groups(df_mixed, "cluster")
# Out:
#             sum_sq     df         F    PR(>F)
# cluster   0.001842    1.0  0.200412  0.654632
# Residual  3.667958  399.0       NaN       NaN

# %%
#compare_error_in_two_groups(df_mixed, "bundesland")

# %%
g = sns.scatterplot(data=df_mixed, x="2019_population", y="error",  hue="ags5")
g.legend_.remove()

# %%
g = sns.scatterplot(data=df_mixed, x="2019_population", y="error",  hue="ags5")
g.legend_.remove()

# %% [markdown]
# ### Linear Regression

# %%
df_mixed.set_index('ags5', drop=True, inplace=True)

# %%
df_mixed['east_west'] = df_mixed['east_west'].astype(str)
df_mixed['eligible_area'] = df_mixed['eligible_area'].astype(str)
df_mixed['cluster'] = df_mixed['cluster'].astype(str)
df_mixed['urban_rural'] = df_mixed['urban_rural'].astype(str)

X = df_mixed.drop(['kreis','pred','error','ground_truth','Unnamed:_0'], axis=1)
Y = np.log(df_mixed['error'])

X = pd.get_dummies(data=X, drop_first=True)

# %%
regr = LinearRegression()
regr.fit(X, Y, sample_weight=None)
# Out:
# LinearRegression()

# %%
stats.summary(regr, X, Y, X.columns)
# Out:
# Residuals:
#     Min     1Q  Median     3Q    Max
# -0.5827 -0.132 -0.0017 0.1451 0.8126
#
#
# Coefficients:
#                                                     Estimate                  Std. Error          t value   p value
# _intercept                                       -100.220133  4.471851e+03+1.063458e+05j  -0.0000+0.0009j  0.999249
# supermarkets_population                             0.003391  1.618300e-02+1.107900e-02j   0.1427-0.0977j  0.862822
# supermarkets_average_distance                       0.000030  1.387000e-02+1.603100e-02j   0.0009-0.0011j  0.998859
# public_transport_availability                       0.002071  6.137000e-03-2.471000e-03j   0.2903+0.1169j  0.754453
# average_distance_bus_stop                           0.000350  1.710000e-04+2.500000e-05j   2.0016-0.2909j  0.043782
# 2019_population_35_to_60                            0.000093  5.746860e-01+1.081461e+00j   0.0000-0.0001j  0.999940
# 2019_population_60_to_80                           -0.000004  5.734380e-01+1.081575e+00j  -0.0000+0.0000j  0.999998
# 2019_population_above_80                           -0.000159  5.740840e-01+1.081847e+00j  -0.0001+0.0001j  0.999897
# no_of_foreigners_2018                               0.000019  2.000000e-06-0.000000e+00j   9.6373+0.1496j  0.000000
# proportion_of_foreigners_in_2018                   -0.012248  1.041900e-02-6.900000e-04j  -1.1704-0.0775j  0.241525
# no_of_births_per_capita                           -22.891689  4.629980e+01-3.300000e-05j  -0.4944-0.0000j  0.621279
# Number_of_Commuters_place_of_work                  -0.000006  1.000000e-06+0.000000e+00j  -5.3591+0.1359j  0.000000
# Number_of_Commuters_on_place_of_residence)         -0.000003  1.000000e-06+0.000000e+00j  -2.0012+0.0273j  0.046029
# Commuter_Balance                                    0.000003  1.000000e-06+0.000000e+00j   3.1751-0.0099j  0.001614
# Proportion_of_in_commuters                         -0.008120  3.880000e-03-1.570000e-04j  -2.0893-0.0844j  0.037161
# Share_of_out_commuters                              0.008184  4.376000e-03-7.800000e-05j   1.8698+0.0332j  0.062197
# Relative_Commuter_Balance                           0.000858  1.344000e-03-2.000000e-06j   0.6386+0.0008j  0.523480
# Commute_within_50km                                -0.001623  5.340000e-03-1.500000e-05j  -0.3040-0.0009j  0.761317
# Commute_within_150km                               -0.013799  1.872800e-02-4.940000e-04j  -0.7363-0.0194j  0.461829
# Commute_within_300km                                0.059991  3.898700e-02+3.588000e-03j   1.5258-0.1404j  0.126245
# number_accomodation_establishments                  0.001603  6.520000e-04+3.000000e-06j   2.4585-0.0113j  0.014372
# number_of_beds                                     -0.000013  6.000000e-06+0.000000e+00j  -2.3676+0.0029j  0.018378
# number_of_guests                                   -0.000000  0.000000e+00+0.000000e+00j  -1.7784+0.0009j  0.076093
# guests_staying_overnight                            0.000000  0.000000e+00-0.000000e+00j   8.4616+0.0286j  0.000000
# number_of_companies                                 0.000627  1.160000e-04+2.000000e-06j   5.3857-0.0710j  0.000000
# number_of_companies_agriculture                    -0.000855  2.180000e-04+1.000000e-06j  -3.9146+0.0178j  0.000106
# number_of_companies_mining                          0.000697  3.119000e-03+1.400000e-05j   0.2235-0.0010j  0.823250
# number_of_companies_manufacturing                  -0.001384  2.360000e-04+0.000000e+00j  -5.8709+0.0019j  0.000000
# number_of_companies_energy                         -0.000751  4.160000e-04+3.000000e-05j  -1.7966+0.1276j  0.072438
# number_of_companies_water_and_sewage                0.002976  1.544000e-03+1.000000e-06j   1.9278-0.0013j  0.054583
# number_of_companies_construction                   -0.000570  2.370000e-04+1.000000e-06j  -2.4007+0.0106j  0.016820
# number_of_companies_repair_motor_vehicles          -0.000783  1.920000e-04+1.000000e-06j  -4.0776+0.0146j  0.000055
# number_of_companies_transport                      -0.001157  3.670000e-04+2.400000e-05j  -3.1381+0.2022j  0.001787
# ags2_12                                             0.548347  4.611030e+03+1.042074e+05j   0.0000-0.0000j  0.999996
# ags2_13                                             0.782372  4.794074e+03+1.012982e+05j   0.0000-0.0000j  0.999994
# ags2_14                                             0.532987  4.452481e+03+1.059507e+05j   0.0000-0.0000j  0.999996
# ags2_15                                             0.457447  4.101992e+03+1.104782e+05j   0.0000-0.0000j  0.999997
# ags2_16                                             0.459325  3.744257e+03+1.151890e+05j   0.0000-0.0000j  0.999997
# cluster_1                                          -2.209772  2.243754e+06-1.193774e+04j  -0.0000-0.0000j  0.999999
# cluster_2                                           0.223768  6.843000e-02+2.185000e-03j   3.2667-0.1043j  0.001175
# urban_rural_urban                                   0.062520  6.540700e-02+9.990000e-04j   0.9556-0.0146j  0.339776
# east_west_west                                      0.111503  4.315459e+03+1.079099e+05j   0.0000-0.0000j  0.999999
# support_area_status_C*                              0.222706  1.829140e-01-2.480000e-04j   1.2175+0.0017j  0.224116
# support_area_status_C**                             0.381548  2.713140e-01+2.800000e-05j   1.4063-0.0001j  0.160413
# support_area_status_C/D                             0.317309  2.616000e-01+6.964000e-03j   1.2121-0.0323j  0.226027
# support_area_status_C/N                             0.252008  4.349590e-01+8.801000e-03j   0.5791-0.0117j  0.562737
# support_area_status_D                               0.469651  5.553650e-01+1.710500e-02j   0.8449-0.0260j  0.398470
# support_area_status_D/N                             0.912929  7.619080e-01+2.225400e-02j   1.1972-0.0350j  0.231742
# support_area_status_N                               0.343082  5.248690e+06-1.904661e+03j   0.0000+0.0000j  1.000000
# eligible_area_not_eligible_area                     0.343082  5.265961e+06+1.710256e+03j   0.0000-0.0000j  1.000000
# ---
# R-squared:  0.76750,    Adjusted R-squared:  0.54188
# F-statistic: 3.40 on 197 features

# %% [markdown]
# ### Sequential Feature Selector

# %%
sfs1 = sfs(regr, k_features = 10,forward=True, floating=False, scoring='r2', cv=5)
sfs1.fit(X, Y)
# Out:
# SequentialFeatureSelector(estimator=LinearRegression(), k_features=10,
#                           scoring='r2')

# %%
summary_table_select = pd.DataFrame.from_dict(sfs1.get_metric_dict()).T
summary_table_select
# Out:
#                                         feature_idx  \
# 1                                            (150,)
# 2                                        (150, 195)
# 3                                    (33, 150, 195)
# 4                                (33, 77, 150, 195)
# 5                           (33, 77, 119, 150, 195)
# 6                      (33, 77, 119, 150, 152, 195)
# 7                 (33, 77, 119, 150, 152, 193, 195)
# 8            (33, 77, 119, 150, 152, 187, 193, 195)
# 9       (33, 77, 119, 150, 152, 173, 187, 193, 195)
# 10  (33, 77, 78, 119, 150, 152, 173, 187, 193, 195)
#
#                                             cv_scores avg_score  \
# 1   [0.17543331977188426, 0.14102970031853357, 0.2...  0.156636
# 2   [0.19521551714881924, 0.21393580537958257, 0.2...  0.215018
# 3   [0.22294822684724847, 0.24723029176994615, 0.3...   0.23762
# 4   [0.2797618841034343, 0.22297004259335285, 0.29...  0.256074
# 5   [0.32572864596760287, 0.23650686884415995, 0.3...  0.275925
# 6   [0.3114882980130049, 0.2806127074162632, 0.381...  0.294389
# 7   [0.3846631147645747, 0.3121512048764987, 0.375...  0.318909
# 8   [0.39200598176115464, 0.2874271122421247, 0.41...  0.336854
# 9   [0.4213859716373589, 0.31446989669463743, 0.40...  0.349842
# 10  [0.41627110158806857, 0.32567932289890433, 0.4...  0.360842
#
#                                         feature_names  ci_bound   std_dev  \
# 1                   (purchasing_power_per_household,)  0.083824  0.065218
# 2   (purchasing_power_per_household, support_area_...  0.094575  0.073583
# 3   (activity_index, purchasing_power_per_househol...  0.113355  0.088194
# 4   (activity_index, number_accomodation_establish...  0.078038  0.060716
# 5   (activity_index, number_accomodation_establish...  0.091387  0.071102
# 6   (activity_index, number_accomodation_establish...  0.090648  0.070527
# 7   (activity_index, number_accomodation_establish...  0.098607   0.07672
# 8   (activity_index, number_accomodation_establish...  0.110234  0.085766
# 9   (activity_index, number_accomodation_establish...  0.103135  0.080243
# 10  (activity_index, number_accomodation_establish...  0.084322  0.065605
#
#      std_err
# 1   0.032609
# 2   0.036791
# 3   0.044097
# 4   0.030358
# 5   0.035551
# 6   0.035263
# 7    0.03836
# 8   0.042883
# 9   0.040121
# 10  0.032803

# %%
list(summary_table_select['feature_names'])[:5]
# Out:
# [('purchasing_power_per_household',),
#  ('purchasing_power_per_household', 'support_area_status_N'),
#  ('activity_index', 'purchasing_power_per_household', 'support_area_status_N'),
#  ('activity_index',
#   'number_accomodation_establishments',
#   'purchasing_power_per_household',
#   'support_area_status_N'),
#  ('activity_index',
#   'number_accomodation_establishments',
#   'no_of_public_institution',
#   'purchasing_power_per_household',
#   'support_area_status_N')]

# %% [markdown]
# ### Ridge

# %%
rr = Ridge(alpha=0.5) 
rr.fit(X, Y)
# Out:
# /Users/amitsasson/venv/DSSGx/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=6.95493e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# Ridge(alpha=0.5)

# %%
stats.summary(rr, X, Y, X.columns)
# Out:
# Residuals:
#     Min      1Q  Median     3Q    Max
# -0.5766 -0.1422 -0.0013 0.1469 0.8604
#
#
# Coefficients:
#                                                    Estimate                  Std. Error          t value   p value
# _intercept                                       -17.917473  4.584489e+03+1.090245e+05j  -0.0000+0.0002j  0.999869
# supermarkets_population                            0.001288 -1.818200e-02-0.000000e+00j  -0.0709+0.0000j  0.943546
# supermarkets_average_distance                      0.000034  8.716000e-03+0.000000e+00j   0.0040-0.0000j  0.996848
# public_transport_availability                     -0.000332  3.593600e-02+0.000000e+00j  -0.0092+0.0000j  0.992628
# average_distance_bus_stop                          0.000396  5.100000e-05+1.120000e-04j   1.3477-2.9307j  0.001360
# average_distance_train_station                     0.000022  1.660000e-04-6.300000e-05j   0.1151+0.0438j  0.902081
# average_distance_public_transport                 -0.000636  4.470000e-04+4.400000e-05j  -1.4100+0.1388j  0.157327
# number_of_students                                 0.000029  3.350000e-04+2.000000e-06j   0.0863-0.0006j  0.931303
# number_of_hospitals                               -0.015626  5.436000e-03+0.000000e+00j  -2.8744+0.0001j  0.004264
# proportion_of_foreigners_in_2018                  -0.002875  1.311800e-02-0.000000e+00j  -0.2192-0.0000j  0.826628
# no_of_births_per_capita                           -0.000647  4.746600e+01-3.400000e-05j  -0.0000-0.0000j  0.999989
# Number_of_Commuters_place_of_work                 -0.000005  1.000000e-06-0.000000e+00j  -3.4434-0.0104j  0.000635
# Number_of_Commuters_on_place_of_residence)        -0.000004  1.000000e-06+0.000000e+00j  -3.0111+0.1452j  0.002738
# Commuter_Balance                                   0.000004  1.000000e-06-0.000000e+00j   3.4620+0.0609j  0.000593
# Proportion_of_in_commuters                        -0.011924  4.428000e-03-0.000000e+00j  -2.6926-0.0001j  0.007387
# Share_of_out_commuters                             0.011254  4.691000e-03-0.000000e+00j   2.3991+0.0001j  0.016892
# Relative_Commuter_Balance                          0.001220  1.371000e-03-0.000000e+00j   0.8899+0.0000j  0.374064
# Commute_within_50km                               -0.005140  5.387000e-03-0.000000e+00j  -0.9541-0.0000j  0.340614
# Commute_within_150km                              -0.006148  1.894800e-02+0.000000e+00j  -0.3245+0.0000j  0.745762
# Commute_within_300km                               0.058947  3.898200e-02+0.000000e+00j   1.5122-0.0000j  0.131283
# number_accomodation_establishments                 0.001059  6.640000e-04+0.000000e+00j   1.5946-0.0008j  0.111588
# number_of_beds                                    -0.000004  5.000000e-06+1.000000e-06j  -0.7720+0.1723j  0.429418
# number_of_guests                                  -0.000000  0.000000e+00+0.000000e+00j  -1.6512+0.0014j  0.099487
# guests_staying_overnight                           0.000000  0.000000e+00+0.000000e+00j   5.0161-0.5135j  0.000001
# number_of_companies                                0.000678  1.160000e-04-1.000000e-06j   5.8241+0.0335j  0.000000
# number_of_companies_agriculture                   -0.000822  2.220000e-04+0.000000e+00j  -3.6959+0.0055j  0.000250
# number_of_companies_mining                        -0.000386  3.114000e-03-0.000000e+00j  -0.1240-0.0000j  0.901350
# number_of_companies_manufacturing                 -0.001265  2.400000e-04-3.000000e-06j  -5.2689-0.0628j  0.000000
# number_of_companies_energy                        -0.000696  4.280000e-04-2.000000e-06j  -1.6275-0.0069j  0.104412
# number_of_companies_water_and_sewage               0.003497  1.574000e-03-0.000000e+00j   2.2213+0.0001j  0.026892
# number_of_companies_construction                  -0.000500  2.430000e-04+0.000000e+00j  -2.0616+0.0025j  0.039895
# number_of_companies_repair_motor_vehicles         -0.000806  1.980000e-04+0.000000e+00j  -4.0778+0.0010j  0.000055
# number_of_companies_transport                     -0.001091  3.310000e-04-5.000000e-06j  -3.2985-0.0478j  0.001058
# number_of_companies_hospitality                   -0.001071  2.240000e-04+4.000000e-06j  -4.7884+0.0760j  0.000002
# number_of_companies_communication                 -0.000948  3.640000e-04-1.000000e-06j  -2.6041-0.0075j  0.009555
# number_of_companies_financial_and_insurance       -0.000478  2.640000e-04-2.000000e-06j  -1.8095-0.0150j  0.071117
# number_of_companies_real_estat                    -0.000794  2.080000e-04+1.400000e-05j  -3.7930+0.2499j  0.000166
# number_of_companies_technical_services            -0.001101  1.830000e-04+2.000000e-06j  -6.0280+0.0698j  0.000000
# ags2_16                                           -0.133269  3.838562e+03+1.180904e+05j  -0.0000+0.0000j  0.999999
# cluster_1                                         -0.088218  2.300270e+06-1.223843e+04j  -0.0000-0.0000j  1.000000
# cluster_2                                          0.279022  7.129700e-02-0.000000e+00j   3.9135+0.0000j  0.000107
# urban_rural_urban                                  0.051285  6.739100e-02-0.000000e+00j   0.7610+0.0000j  0.447098
# east_west_west                                     0.099898  4.424160e+03+1.106279e+05j   0.0000-0.0000j  0.999999
# support_area_status_C*                             0.002542  1.887150e-01+0.000000e+00j   0.0135-0.0000j  0.989260
# support_area_status_C**                            0.070112  2.802880e-01+0.000000e+00j   0.2501-0.0000j  0.802604
# support_area_status_C/D                           -0.008617  2.647700e-01+0.000000e+00j  -0.0325+0.0000j  0.974054
# support_area_status_C/N                           -0.161211  4.522130e-01+0.000000e+00j  -0.3565+0.0000j  0.721659
# support_area_status_D                             -0.056366  5.845770e-01+0.000000e+00j  -0.0964+0.0000j  0.923234
# support_area_status_D/N                            0.232421  7.955060e-01+0.000000e+00j   0.2922-0.0000j  0.770310
# support_area_status_N                             -0.040123  5.380894e+06-1.952732e+03j  -0.0000-0.0000j  1.000000
# eligible_area_not_eligible_area                   -0.040123  5.398601e+06+1.753249e+03j  -0.0000+0.0000j  1.000000
# ---
# R-squared:  0.75564,    Adjusted R-squared:  0.51851
# F-statistic: 3.19 on 197 features

# %% [markdown]
# household_with_kids
# public_transport_per_1000_inhabitants
# number_of_companies_repair_motor_vehicles
# number_of_companies_hospitality
# number_of_companies_technical_services
# debtor_quota
# purchasing_power_per_household

# %% [markdown]
# ## Look at the variables that are important for predicting the error

# %%
g = sns.scatterplot(data=df_mixed, x="Number_of_Commuters_on_place_of_residence)", y="error",  hue="ags5")
g.set_title('Residuals')
g.legend_.remove()
plt.savefig('Commuters_Residuals.png')

# %%
g = sns.scatterplot(data=df_mixed, x="debtor_quota", y="error",  hue="ags5")
g.set_title('Residuals')
g.legend_.remove()
plt.savefig('debtor_quota_Residuals.png')

# %%
sns.kdeplot(data=df_mixed, x="debtor_quota", common_norm=False)
# Out:
# <AxesSubplot:xlabel='debtor_quota', ylabel='Density'>

# %%
g = sns.scatterplot(data=df_mixed, x="purchasing_power_per_household", y="error",  hue="ags5")
g.set_title('Residuals')
g.legend_.remove()
plt.savefig('purchasing_power_Residuals.png')

# %%
sns.kdeplot(data=df_mixed, x="purchasing_power_per_household", common_norm=False)
# Out:
# <AxesSubplot:xlabel='purchasing_power_per_household', ylabel='Density'>

# %%
g = sns.scatterplot(data=df_mixed, x="moor_area_percentage", y="error",  hue="ags5")
g.legend_.remove()

# %%
df['diff_pred'] = df.groupby('ags5')['pred'].diff(1)

# %%
df['diff_sign'] =  np.where(abs(df['diff_pred']) + abs(df['diff_ground_truth']) == abs(df['diff_pred'] + df['diff_ground_truth']), 'same', 'different')

# %%
df['diff_sign'].value_counts(normalize=True) * 100
# Out:
# same         72.412718
# different    27.587282
# Name: diff_sign, dtype: float64
