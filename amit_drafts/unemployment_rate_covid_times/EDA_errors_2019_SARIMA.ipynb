# %%
import os
import mlflow
import numpy as np
import pandas as pd

from math import sqrt
from joblib import delayed
from joblib import Parallel

from warnings import catch_warnings
from warnings import filterwarnings
from multiprocessing import cpu_count
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.statespace.sarimax import SARIMAX

import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from matplotlib import pyplot

from pathlib import Path
from functools import reduce
from datetime import datetime

from prophet import Prophet

import random
from scipy.stats import ttest_ind
import statsmodels.api as sm
from statsmodels.formula.api import ols
from sklearn.linear_model import LinearRegression, RidgeCV, Ridge
from regressors import stats
from mlxtend.feature_selection import SequentialFeatureSelector as sfs

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv('./../error_dfs/error_2019_ARIMA.csv', converters={'ags2': str, 'ags5': str} )

# %%
# fix ags5 missing 0 
df['ags5'] = np.where(df.ags5.str.len() ==4, '0' + df['ags5'], df['ags5'])

# %%
# add 'ags2','bundesland','kreis'
df2 = pd.read_csv('./../corona_data_sets/oeffentliche_finanzen.csv', converters={'ags2': str, 'ags5': str} )
df = pd.merge(df, df2[['ags2','ags5','bundesland','kreis']])
df['date'] = pd.to_datetime(df['date'], format = '%Y-%m-%d')
df
# Out:
#        ags5       date  ground_truth      pred     error ags2  \
# 0     01001 2019-01-31           8.2  7.801405  0.398595   01
# 1     01001 2019-02-28           7.8  8.052910  0.252910   01
# 2     01001 2019-03-31           7.8  7.763520  0.036480   01
# 3     01001 2019-04-30           7.6  7.634104  0.034104   01
# 4     01001 2019-05-31           7.7  7.337496  0.362504   01
# ...     ...        ...           ...       ...       ...  ...
# 4807  16077 2019-08-31           7.0  6.978600  0.021400   16
# 4808  16077 2019-09-30           6.5  6.839895  0.339895   16
# 4809  16077 2019-10-31           6.5  6.451817  0.048183   16
# 4810  16077 2019-11-30           6.3  6.556410  0.256410   16
# 4811  16077 2019-12-31           6.5  6.439946  0.060054   16
#
#               bundesland             kreis
# 0     Schleswig-Holstein  Flensburg, Stadt
# 1     Schleswig-Holstein  Flensburg, Stadt
# 2     Schleswig-Holstein  Flensburg, Stadt
# 3     Schleswig-Holstein  Flensburg, Stadt
# 4     Schleswig-Holstein  Flensburg, Stadt
# ...                  ...               ...
# 4807           Thüringen  Altenburger Land
# 4808           Thüringen  Altenburger Land
# 4809           Thüringen  Altenburger Land
# 4810           Thüringen  Altenburger Land
# 4811           Thüringen  Altenburger Land
#
# [4812 rows x 8 columns]

# %% [markdown]
# ## Plot each variable

# %%
g = sns.lineplot(data=df, x="date", y="pred",  hue="ags5")
g.legend_.remove()

# %%
g = sns.lineplot(data=df, x="date", y="error",  hue="ags5")
g.legend_.remove()

# %%
g = sns.lineplot(data=df, x="date", y="ground_truth",  hue="ags5")
g.legend_.remove()

# %%
g = sns.scatterplot(data=df, x="pred", y="error",  hue="ags5")
g.legend_.remove()

# %% [markdown]
# ## Plot sample to compare prediction to ground truth

# %%
df_long = df.melt(id_vars=['date','ags5','ags2','bundesland','kreis'], var_name='y_type', value_name='vals')

# %%
df_long = df_long[df_long['y_type'].isin(['ground_truth','pred'])]

# %%
sample_args = random.sample(list(set(df_long['ags5'])), 30)
df_sample = df_long[df_long['ags5'].isin(sample_args)]

# %%
g = sns.lineplot(data=df_sample, x="date", y="vals",  hue="ags5", style="y_type")
g.legend_.remove()

# %% [markdown]
# ## Look into mean errors

# %%
df_mean_error = df.groupby(['ags5','ags2','bundesland','kreis']).mean()
df_mean_error
# Out:
#                                                       ground_truth      pred  \
# ags5  ags2 bundesland         kreis
# 01001 01   Schleswig-Holstein Flensburg, Stadt            7.958333  7.853025
# 01002 01   Schleswig-Holstein Kiel, Landeshauptstadt      7.591667  7.579645
# 01003 01   Schleswig-Holstein Lübeck, Hansestadt          7.275000  7.274474
# 01004 01   Schleswig-Holstein Neumünster, Stadt           7.900000  7.881733
# 01051 01   Schleswig-Holstein Dithmarschen                5.500000  5.489077
# ...                                                            ...       ...
# 16073 16   Thüringen          Saalfeld-Rudolstadt         5.241667  5.257047
# 16074 16   Thüringen          Saale-Holzland-Kreis        4.141667  4.142775
# 16075 16   Thüringen          Saale-Orla-Kreis            4.600000  4.630328
# 16076 16   Thüringen          Greiz                       4.641667  4.598022
# 16077 16   Thüringen          Altenburger Land            7.058333  7.097667
#
#                                                          error
# ags5  ags2 bundesland         kreis
# 01001 01   Schleswig-Holstein Flensburg, Stadt        0.210342
# 01002 01   Schleswig-Holstein Kiel, Landeshauptstadt  0.118261
# 01003 01   Schleswig-Holstein Lübeck, Hansestadt      0.095788
# 01004 01   Schleswig-Holstein Neumünster, Stadt       0.090659
# 01051 01   Schleswig-Holstein Dithmarschen            0.058198
# ...                                                        ...
# 16073 16   Thüringen          Saalfeld-Rudolstadt     0.085753
# 16074 16   Thüringen          Saale-Holzland-Kreis    0.095621
# 16075 16   Thüringen          Saale-Orla-Kreis        0.088846
# 16076 16   Thüringen          Greiz                   0.063197
# 16077 16   Thüringen          Altenburger Land        0.095283
#
# [401 rows x 3 columns]

# %%
g = sns.scatterplot(data=df_mean_error, x="ground_truth", y="error",  hue="ags5")
g.legend_.remove()

# %%
g = sns.scatterplot(data=df_mean_error, x="pred", y="error",  hue="ags5")
g.legend_.remove()

# %%
df_mean_error.sort_values(by = ['error'], ascending=False)
# Out:
#                                                      ground_truth       pred  \
# ags5  ags2 bundesland             kreis
# 03401 03   Niedersachsen          Delmenhorst            9.366667   9.295457
# 05513 05   Nordrhein-Westfalen    Gelsenkirchen         12.816667  12.759603
# 09464 09   Freistaat Bayern       Hof                    5.641667   5.616806
# 01001 01   Schleswig-Holstein     Flensburg, Stadt       7.958333   7.853025
# 12053 12   Brandenburg            Frankfurt (Oder)       7.916667   7.938185
# ...                                                           ...        ...
# 09673 09   Freistaat Bayern       Rhön-Grabfeld          2.475000   2.453493
# 09175 09   Freistaat Bayern       Ebersberg              1.816667   1.807418
# 09562 09   Freistaat Bayern       Erlangen               3.533333   3.527779
# 13072 13   Mecklenburg-Vorpommern Landkreis Rostock      5.250000   5.253321
# 06432 06   Hessen                 Darmstadt-Dieburg      4.308333   4.306037
#
#                                                         error
# ags5  ags2 bundesland             kreis
# 03401 03   Niedersachsen          Delmenhorst        0.258285
# 05513 05   Nordrhein-Westfalen    Gelsenkirchen      0.242698
# 09464 09   Freistaat Bayern       Hof                0.229453
# 01001 01   Schleswig-Holstein     Flensburg, Stadt   0.210342
# 12053 12   Brandenburg            Frankfurt (Oder)   0.196126
# ...                                                       ...
# 09673 09   Freistaat Bayern       Rhön-Grabfeld      0.035406
# 09175 09   Freistaat Bayern       Ebersberg          0.034685
# 09562 09   Freistaat Bayern       Erlangen           0.034256
# 13072 13   Mecklenburg-Vorpommern Landkreis Rostock  0.033451
# 06432 06   Hessen                 Darmstadt-Dieburg  0.032081
#
# [401 rows x 3 columns]

# %%
sns.kdeplot(data=df_mean_error, x="error", common_norm=False)
# Out:
# <AxesSubplot:xlabel='error', ylabel='Density'>

# %%
# Out:
# <AxesSubplot:xlabel='error', ylabel='Density'>

# %% [markdown]
# ## Look into errors

# %%
df.sort_values(by = ['error'], ascending=False)
# Out:
#        ags5        date  ground_truth      pred     error ags2  \
# 2356  08222  2019-05-31           5.5  4.715860  0.784140   08
# 532   03401  2019-05-31           9.9  9.232759  0.667241   03
# 1275  05914  2019-04-30           9.9  9.253225  0.646775   05
# 4620  16062  2019-01-31           8.0  7.369784  0.630216   16
# 3318  09476  2019-07-31           3.4  2.821355  0.578645   09
# ...     ...         ...           ...       ...       ...  ...
# 1653  06632  2019-10-31           3.4  3.400248  0.000248   06
# 661   03457  2019-02-28           5.9  5.899752  0.000248   03
# 2813  09180  2019-06-30           2.2  2.200169  0.000169   09
# 4584  16055  2019-01-31           6.3  6.300128  0.000128   16
# 99    01056  2019-04-30           4.5  4.500014  0.000014   01
#
#                bundesland                   kreis
# 2356    Baden-Württemberg                Mannheim
# 532         Niedersachsen             Delmenhorst
# 1275  Nordrhein-Westfalen                   Hagen
# 4620            Thüringen              Nordhausen
# 3318     Freistaat Bayern                 Kronach
# ...                   ...                     ...
# 1653               Hessen      Hersfeld-Rotenburg
# 661         Niedersachsen                    Leer
# 2813     Freistaat Bayern  Garmisch-Partenkirchen
# 4584            Thüringen                  Weimar
# 99     Schleswig-Holstein               Pinneberg
#
# [4812 rows x 8 columns]

# %%
df['diff_ground_truth'] = df.groupby('ags5')['ground_truth'].diff(1) 
df['diff_ground_truth_abs'] = df['diff_ground_truth'].abs()

# %%
g = sns.scatterplot(data=df, x="diff_ground_truth_abs", y="error",  hue="ags5")
g.legend_.remove()

# %%
sns.kdeplot(data=df, x="error", common_norm=False)
# Out:
# <AxesSubplot:xlabel='error', ylabel='Density'>

# %%
sns.kdeplot(data=df, x="error", common_norm=False,log_scale=True)
# Out:
# <AxesSubplot:xlabel='error', ylabel='Density'>

# %% [markdown]
# # Load structural data

# %%
df_structural = pd.read_csv('./../final_dfs/for_modeling/df_final_stationery.csv', converters={'ags2': str, 'ags5': str} )
df_structural
# Out:
#      cluster                   kreis   ags5 ags2  supermarkets_population  \
# 0          0        Flensburg, Stadt  01001   01                       92
# 1          2  Kiel, Landeshauptstadt  01002   01                       92
# 2          2      Lübeck, Hansestadt  01003   01                       90
# 3          0       Neumünster, Stadt  01004   01                       85
# 4          0            Dithmarschen  01051   01                       51
# ..       ...                     ...    ...  ...                      ...
# 396        0     Saalfeld-Rudolstadt  16073   16                       62
# 397        0    Saale-Holzland-Kreis  16074   16                       54
# 398        0        Saale-Orla-Kreis  16075   16                       54
# 399        0                   Greiz  16076   16                       55
# 400        0        Altenburger Land  16077   16                       62
#
#      supermarkets_average_distance  public_transport_availability  \
# 0                              500                             35
# 1                              460                             37
# 2                              532                             37
# 3                              588                             37
# 4                             1864                             35
# ..                             ...                            ...
# 396                           1423                             37
# 397                           1677                             38
# 398                           1686                             35
# 399                           1654                             38
# 400                           1458                             35
#
#      average_distance_bus_stop  average_distance_train_station  \
# 0                          240                            2901
# 1                          268                            2037
# 2                          297                            1927
# 3                          316                            1648
# 4                          448                            3517
# ..                         ...                             ...
# 396                        341                            2492
# 397                        343                            3419
# 398                        449                            3172
# 399                        608                            2779
# 400                        584                            3628
#
#      average_distance_public_transport  ...  room_type_location  \
# 0                                  240  ...                   2
# 1                                  265  ...                   2
# 2                                  294  ...                   1
# 3                                  313  ...                   2
# 4                                  443  ...                   4
# ..                                 ...  ...                 ...
# 396                                322  ...                   3
# 397                                340  ...                   3
# 398                                444  ...                   3
# 399                                563  ...                   3
# 400                                574  ...                   3
#
#      district_settlement_structure  type_of_settlement_structure  \
# 0                                4                             3
# 1                                1                             2
# 2                                1                             2
# 3                                3                             2
# 4                                4                             3
# ..                             ...                           ...
# 396                              4                             2
# 397                              3                             2
# 398                              4                             2
# 399                              2                             2
# 400                              3                             2
#
#      urban_/_rural  metropolitan_region  metropolitan_area  east_west  \
# 0                2                   99                 99          1
# 1                1                   99                 99          1
# 2                1                    5                 99          1
# 3                2                    5                 99          1
# 4                2                    5                 99          1
# ..             ...                  ...                ...        ...
# 396              2                   99                 99          2
# 397              2                   99                 99          2
# 398              2                   99                 99          2
# 399              1                   99                 99          2
# 400              2                    7                 99          2
#
#      border_proximity  support_area_status  eligible_area
# 0                   1                    C              1
# 1                   0                  C/D              1
# 2                   0                  C/D              1
# 3                   0                    D              1
# 4                   0                    C              1
# ..                ...                  ...            ...
# 396                 0                   C*              1
# 397                 0                   C*              1
# 398                 2                   C*              1
# 399                 0                   C*              1
# 400                 0                   C*              1
#
# [401 rows x 179 columns]

# %% [markdown]
# ### Merge to df with mean errors

# %%
df_mixed = pd.merge(df_mean_error, df_structural, on = ['ags5','ags2'])
list(df_mixed.columns)
# Out:
# ['ags5',
#  'ags2',
#  'ground_truth',
#  'pred',
#  'error',
#  'cluster',
#  'kreis',
#  'supermarkets_population',
#  'supermarkets_average_distance',
#  'public_transport_availability',
#  'average_distance_bus_stop',
#  'average_distance_train_station',
#  'average_distance_public_transport',
#  'Unnamed:_0',
#  'number_of_students',
#  'number_of_hospitals',
#  'number_of_hospital_beds',
#  'number_of_hospital_beds_adj',
#  'hospital_patiants',
#  'households_of_1_person',
#  'households_of_2_person',
#  'households_of_3_person',
#  'households_of_4_person',
#  'households_of_5_person_or_more',
#  'household_with_kids',
#  'household_with_kids_under_3',
#  'household_with_kids_over_3_under_6',
#  'household_with_kids_over_6_under_10',
#  'household_with_kids_over_10_under_15',
#  'household_with_kids_over_15_under_18',
#  'household_with_double_income_no_kids',
#  'car_density',
#  'no_of_paths_per_person_and_day',
#  'kilometers_per_person_and_day',
#  '_percentage_out_of_home',
#  'share_of_journeys_on_foot',
#  'share_of_journeys_on_bike',
#  'proportion_of_motorised_vehicle_passenger',
#  'share_of_motorised_vehicle_driver',
#  'share_of_public_transport_',
#  'public_transport_per_1000_inhabitants',
#  'activity_index',
#  'municipal_dept_per_capita',
#  'municipal_tax_per_capita',
#  'municipal_tax_per_capita.1',
#  'no_of_births_in_2018',
#  '2018_population',
#  '2019_population',
#  '2018_men_population',
#  '2018_women_population',
#  '2018_population_under_3_yrs',
#  '2018_population_3_to_6',
#  '2018_population_6_to_10',
#  '2018_population_10_to_15',
#  '2018_population_15_to_18',
#  '2018_population_18_to_20',
#  '2018_population_20_to_25',
#  '2018_population_25_to_30',
#  '2018_population_30_to_35',
#  '2018_population_35_to_40',
#  '2018_population_40_to_45',
#  '2018_population_45_to_50',
#  '2018_population_50_to_55',
#  '2018_population_55_to_60',
#  '2018_population_60_to_65',
#  '2018_population_65_to_75',
#  '2018_population_above_75',
#  '2019_population_under_5',
#  '2019_population_5_to_15',
#  '2019_population_15_to_35',
#  '2019_population_35_to_60',
#  '2019_population_60_to_80',
#  '2019_population_above_80',
#  'no_of_foreigners_2018',
#  'proportion_of_foreigners_in_2018',
#  'no_of_births_per_capita',
#  'Number_of_Commuters_place_of_work',
#  'Number_of_Commuters_on_place_of_residence)',
#  'Commuter_Balance',
#  'Proportion_of_in_commuters',
#  'Share_of_out_commuters',
#  'Relative_Commuter_Balance',
#  'Commute_within_50km',
#  'Commute_within_150km',
#  'Commute_within_300km',
#  'number_accomodation_establishments',
#  'number_of_beds',
#  'number_of_guests',
#  'guests_staying_overnight',
#  'number_of_companies',
#  'number_of_companies_agriculture',
#  'number_of_companies_mining',
#  'number_of_companies_manufacturing',
#  'number_of_companies_energy',
#  'number_of_companies_water_and_sewage',
#  'number_of_companies_construction',
#  'number_of_companies_repair_motor_vehicles',
#  'number_of_companies_transport',
#  'number_of_companies_hospitality',
#  'number_of_companies_communication',
#  'number_of_companies_financial_and_insurance',
#  'number_of_companies_real_estat',
#  'number_of_companies_technical_services',
#  'number_of_companies_economic_services',
#  'number_of_companies_administration',
#  'number_of_companies_education',
#  'number_of_companies_health_and_social_services',
#  'number_of_companies_arts_entertainment',
#  'number_of_companies_rendering_other_services',
#  'number_of_companies_domestic_staff',
#  'number_of_companies_extraterritorial',
#  'number_of_companies_1_to_4_employees',
#  'number_of_companies_5_to_49_employees',
#  'number_of_companies_50_to_400_employees',
#  'number_of_companies_500_or_more_employees',
#  'no_of_hairdressers',
#  'no_of_restraunts',
#  'no_of_branches',
#  'no_of_commertial_units',
#  'no_of_shopping_malls',
#  'no_of_clubs',
#  'no_of_slaughterhouse',
#  'no_of_education_centers',
#  'no_of_shopping',
#  'no_of_free_time',
#  'no_of_tourism_points',
#  'no_of_food_and_drink',
#  'no_of_public_institution',
#  'no_of_traffic_centers',
#  'no_of_health_centers',
#  'no_of_business',
#  'total_area',
#  'Residential_area_percentage',
#  'industrial_/_commertial_area_percentage',
#  'dump_area_percentage',
#  'mining_area_percentage',
#  'open_pit,_mine,_quarry_area_percentage',
#  'mixed_use_area_percentage',
#  'special_functional_character_land_percentage',
#  'sport,_leisure,_recreation_area_percentage',
#  'cemetry_area_percentage',
#  'road_area_percentage',
#  'space_area_percentage',
#  'rail_traffic_area_percentage',
#  'air_traffic_area_percentage',
#  'shipping_area_percentage',
#  'agri_area_percentage',
#  'forrest_area_percentage',
#  'wood_area_percentage',
#  'health_area_percentage',
#  'moor_area_percentage',
#  'swamp_area_percentage',
#  'without_vegetation_area_percentage',
#  'flowing_water_percentage',
#  'harbor_basin_percentage',
#  'standing_water_percentage',
#  'sea_percentage',
#  'median_income',
#  'purchasing_power_per_household',
#  'purchasing_power_per_person',
#  'debtor_quota',
#  'household_in_income_calss_1',
#  'household_in_income_calss_2',
#  'household_in_income_calss_3',
#  'household_in_income_calss_4',
#  'household_in_income_calss_5',
#  'household_in_income_calss_6',
#  'labor_market_region',
#  'growing_/_shrinking_circles',
#  'labor_market_type',
#  'grw_funding_framework',
#  'settlement_structure_type_of_labor_market_region',
#  'room_type_location',
#  'district_settlement_structure',
#  'type_of_settlement_structure',
#  'urban_/_rural',
#  'metropolitan_region',
#  'metropolitan_area',
#  'east_west',
#  'border_proximity',
#  'support_area_status',
#  'eligible_area']

# %% [markdown]
# ### Compare error in two_groups

# %%
#function to do that cor a spesific column 
def compare_error_in_two_groups(df, column_name): 
    sns.kdeplot(data=df, x="error", hue=column_name,  common_norm=False)
    plt.show()
    df[column_name] = df[column_name].astype(str)
    one, two = list(set(df[column_name]))
    df_one = df[df[column_name]==one]
    df_two = df[df[column_name]==two]
    return ttest_ind(df_one['error'], df_two['error'], equal_var=False)

# %%
compare_error_in_two_groups(df_mixed, 'eligible_area')
# Out:
# Ttest_indResult(statistic=-8.607252182961957, pvalue=5.091778629047658e-16)

# %%
compare_error_in_two_groups(df_mixed, 'east_west')
# Out:
# Ttest_indResult(statistic=4.474059045710493, pvalue=1.762248993054819e-05)

# %%
compare_error_in_two_groups(df_mixed, 'urban_/_rural')
# Out:
# Ttest_indResult(statistic=-1.693760249351441, pvalue=0.09109470182985409)

# %% [markdown]
# ### Compare compare error in multiple groups

# %%
#function to do that cor a spesific column 
def compare_error_in_two_groups(df, column_name): 
    sns.kdeplot(data=df, x="error", hue=column_name,  common_norm=False)
    plt.show()
    mod = ols(f'error ~ {column_name}',
                data=df).fit()
                
    aov_table = sm.stats.anova_lm(mod, typ=2)
    print(aov_table)

# %%
compare_error_in_two_groups(df_mixed, "cluster")
# Out:
#             sum_sq     df         F    PR(>F)
# cluster   0.002859    1.0  2.293594  0.130701
# Residual  0.497380  399.0       NaN       NaN

# %%
compare_error_in_two_groups(df_mixed, "ags2")
# Out:
# /Users/amitsasson/venv/DSSGx/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/amitsasson/venv/DSSGx/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
#             sum_sq     df         F        PR(>F)
# ags2      0.072533   15.0  4.352694  1.498724e-07
# Residual  0.427706  385.0       NaN           NaN

# %%
g = sns.scatterplot(data=df_mixed, x="2019_population", y="error",  hue="ags5")
g.legend_.remove()

# %%
g = sns.scatterplot(data=df_mixed, x="2019_population", y="error",  hue="ags5")
g.legend_.remove()

# %% [markdown]
# ### Linear Regression

# %%
df_mixed.set_index('ags5', drop=True, inplace=True)

# %%
df_mixed['east_west'] = df_mixed['east_west'].astype(str)
df_mixed['eligible_area'] = df_mixed['eligible_area'].astype(str)
df_mixed['cluster'] = df_mixed['cluster'].astype(str)
df_mixed['urban_/_rural'] = df_mixed['urban_/_rural'].astype(str)

X = df_mixed.drop(['kreis','pred','error','ground_truth','Unnamed:_0'], axis=1)
Y = np.log(df_mixed['error'])

X = pd.get_dummies(data=X, drop_first=True)

# %%
regr = LinearRegression()
regr.fit(X, Y, sample_weight=None)
# Out:
# LinearRegression()

# %%
stats.summary(regr, X, Y, X.columns)
# Out:
# Residuals:
#    Min      1Q  Median     3Q    Max
# -0.602 -0.1207 -0.0217 0.1192 0.7317
#
#
# Coefficients:
#                                                     Estimate                  Std. Error          t value   p value
# _intercept                                       -154.929031  2.316904e+05+1.200000e-05j  -0.0007+0.0000j  0.999467
# supermarkets_population                             0.007148  3.660000e-03+3.828000e-03j   0.9326-0.9754j  0.177945
# supermarkets_average_distance                       0.000087  2.600000e-03+4.580000e-04j   0.0323-0.0057j  0.973815
# public_transport_availability                       0.001616  1.689000e-03+8.000000e-05j   0.9547-0.0454j  0.339767
# average_distance_bus_stop                           0.000254  2.360000e-04-1.000000e-05j   1.0729+0.0446j  0.283569
# average_distance_train_station                      0.000011  5.600000e-05+2.000000e-06j   0.2003-0.0058j  0.841300
# average_distance_public_transport                  -0.000272  3.590000e-04+1.200000e-05j  -0.7567+0.0248j  0.449413
# number_of_students                                  0.000024  1.100000e-05+1.000000e-06j   2.1943-0.1136j  0.028576
# number_of_hospitals                                -0.016331  4.196000e-03+4.420000e-04j  -3.8493+0.4057j  0.000127
# number_of_hospital_beds                            -0.000142  7.200000e-05-4.000000e-06j  -1.9760-0.0993j  0.048562
# number_of_hospital_beds_adj                         0.014343  3.952000e-03+4.700000e-04j   3.5786-0.4258j  0.000353
# hospital_patiants                                  -0.000004  3.000000e-06+0.000000e+00j  -1.3407+0.0183j  0.180742
# households_of_1_person                              0.000028  1.500000e-05+0.000000e+00j   1.7845-0.0563j  0.074962
# households_of_2_person                              0.000043  2.500000e-05+1.000000e-06j   1.6945-0.0340j  0.090879
# households_of_3_person                              0.000170  5.600000e-05+0.000000e+00j   3.0350-0.0198j  0.002562
# households_of_4_person                              0.000184  1.020000e-04-0.000000e+00j   1.7981+0.0074j  0.072906
# households_of_5_person_or_more                      0.000130  2.170000e-04-0.000000e+00j   0.6013+0.0004j  0.547949
# household_with_kids                                -0.000317  4.300000e-05-0.000000e+00j  -7.3033-0.0461j  0.000000
# household_with_kids_under_3                         0.000204  2.720000e-04+1.000000e-06j   0.7488-0.0018j  0.454414
# household_with_kids_over_3_under_6                 -0.000047  3.540000e-04+3.000000e-06j  -0.1336+0.0013j  0.893793
# household_with_kids_over_6_under_10                 0.000568  2.150000e-04-4.000000e-06j   2.6401+0.0496j  0.008600
# border_proximity                                   -0.032741  2.114500e-02+1.000000e-06j  -1.5484+0.0001j  0.122318
# ags2_02                                            -0.736384  3.789755e+06+3.060000e-04j  -0.0000+0.0000j  1.000000
# ags2_03                                             0.025372  1.094010e-01-0.000000e+00j   0.2319+0.0000j  0.816720
# ags2_04                                            -0.525410  3.859690e-01+0.000000e+00j  -1.3613+0.0000j  0.174193
# ags2_05                                            -0.019536  1.325800e-01-0.000000e+00j  -0.1473-0.0000j  0.882930
# ags2_06                                            -0.079888  1.344750e-01+1.000000e-06j  -0.5941+0.0000j  0.552799
# ags2_07                                             0.073998  1.411210e-01+0.000000e+00j   0.5244-0.0000j  0.600318
# ags2_08                                            -0.070448  1.676990e-01-0.000000e+00j  -0.4201-0.0000j  0.674650
# ags2_09                                            -0.117583  2.080940e-01+7.000000e-06j  -0.5650+0.0000j  0.572357
# ags2_10                                             0.250551  2.338110e-01+0.000000e+00j   1.0716-0.0000j  0.284548
# ags2_11                                            -0.623338  4.282031e+06+1.190000e-04j  -0.0000+0.0000j  1.000000
# ags2_12                                            -0.023003  2.786231e+05+5.000000e-06j  -0.0000+0.0000j  1.000000
# ags2_13                                            -0.059293  2.788095e+05-7.000000e-06j  -0.0000-0.0000j  1.000000
# ags2_14                                             0.251032  2.786398e+05+1.300000e-05j   0.0000-0.0000j  0.999999
# ags2_15                                             0.130545  2.787815e+05+0.000000e+00j   0.0000-0.0000j  1.000000
# ags2_16                                             0.010697  2.787572e+05+1.500000e-05j   0.0000-0.0000j  1.000000
# cluster_1                                          -1.359722  3.789967e+06-3.620000e-04j  -0.0000-0.0000j  1.000000
# cluster_2                                           0.116332  6.451200e-02+1.000000e-06j   1.8033-0.0000j  0.072101
# urban_/_rural_2                                    -0.016007  5.980600e-02-0.000000e+00j  -0.2676-0.0000j  0.789110
# east_west_2                                        -0.313359  2.785748e+05+1.000000e-06j  -0.0000+0.0000j  0.999999
# support_area_status_C*                              0.371092  1.670650e-01+4.000000e-06j   2.2212-0.0001j  0.026894
# support_area_status_C**                             0.825873  2.495290e-01+1.000000e-06j   3.3097-0.0000j  0.001019
# support_area_status_C/D                             0.607339  2.337090e-01+3.000000e-06j   2.5987-0.0000j  0.009704
# support_area_status_C/N                             0.966480  3.988470e-01+1.000000e-06j   2.4232-0.0000j  0.015828
# support_area_status_D                               1.085343  5.009570e-01+5.000000e-06j   2.1665-0.0000j  0.030860
# support_area_status_D/N                             1.174509  6.983270e-01+0.000000e+00j   1.6819-0.0000j  0.093371
# support_area_status_N                               0.754439  2.316213e+05-1.100000e-05j   0.0000+0.0000j  0.999997
# eligible_area_1                                    -0.754439  2.316538e+05+8.900000e-05j  -0.0000+0.0000j  0.999997
# ---
# R-squared:  0.73809,    Adjusted R-squared:  0.48392
# F-statistic: 2.90 on 197 features

# %% [markdown]
# ### Sequential Feature Selector

# %%
sfs1 = sfs(regr, k_features = 10,forward=True, floating=False, scoring='r2', cv=5)
sfs1.fit(X, Y)
# Out:
# SequentialFeatureSelector(estimator=LinearRegression(), k_features=10,
#                           scoring='r2')

# %%
summary_table_select = pd.DataFrame.from_dict(sfs1.get_metric_dict()).T
summary_table_select
# Out:
#                                        feature_idx  \
# 1                                           (150,)
# 2                                       (150, 152)
# 3                                   (69, 150, 152)
# 4                              (69, 142, 150, 152)
# 5                         (69, 142, 150, 152, 163)
# 6                     (69, 77, 142, 150, 152, 163)
# 7                 (69, 77, 80, 142, 150, 152, 163)
# 8            (69, 77, 80, 123, 142, 150, 152, 163)
# 9       (69, 77, 80, 123, 142, 150, 152, 160, 163)
# 10  (69, 76, 77, 80, 123, 142, 150, 152, 160, 163)
#
#                                             cv_scores avg_score  \
# 1   [0.3220342717250645, 0.31046100919565667, 0.28...  0.254637
# 2   [0.34602120985294327, 0.3758963265019486, 0.41...  0.313643
# 3   [0.38321792890647854, 0.3341682944258302, 0.46...  0.351077
# 4   [0.40723198283816253, 0.3220624335802921, 0.47...  0.364437
# 5   [0.4250726923971049, 0.32457882877180677, 0.47...    0.3812
# 6   [0.4336087227560974, 0.34336353128168096, 0.47...  0.392184
# 7   [0.4350519451340984, 0.3085669867144646, 0.497...  0.402672
# 8   [0.4375904596962312, 0.3342781204062526, 0.505...  0.409854
# 9   [0.41301273417591955, 0.3428226707480546, 0.51...  0.423133
# 10  [0.41734189515667786, 0.34859550032007247, 0.5...  0.430387
#
#                                         feature_names  ci_bound   std_dev  \
# 1                   (purchasing_power_per_household,)  0.085344  0.066401
# 2      (purchasing_power_per_household, debtor_quota)   0.10829  0.084253
# 3   (Number_of_Commuters_on_place_of_residence), p...  0.088082  0.068531
# 4   (Number_of_Commuters_on_place_of_residence), m...  0.087341  0.067955
# 5   (Number_of_Commuters_on_place_of_residence), m...  0.081558  0.063455
# 6   (Number_of_Commuters_on_place_of_residence), n...  0.072261  0.056222
# 7   (Number_of_Commuters_on_place_of_residence), n...   0.08544  0.066475
# 8   (Number_of_Commuters_on_place_of_residence), n...  0.076966  0.059882
# 9   (Number_of_Commuters_on_place_of_residence), n...   0.07217   0.05615
# 10  (Number_of_Commuters_on_place_of_residence), C...  0.067869  0.052804
#
#      std_err
# 1     0.0332
# 2   0.042126
# 3   0.034265
# 4   0.033977
# 5   0.031727
# 6   0.028111
# 7   0.033238
# 8   0.029941
# 9   0.028075
# 10  0.026402

# %%
list(summary_table_select['feature_names'])[:5]
# Out:
# [('purchasing_power_per_household',),
#  ('purchasing_power_per_household', 'debtor_quota'),
#  ('Number_of_Commuters_on_place_of_residence)',
#   'purchasing_power_per_household',
#   'debtor_quota'),
#  ('Number_of_Commuters_on_place_of_residence)',
#   'moor_area_percentage',
#   'purchasing_power_per_household',
#   'debtor_quota'),
#  ('Number_of_Commuters_on_place_of_residence)',
#   'moor_area_percentage',
#   'purchasing_power_per_household',
#   'debtor_quota',
#   'settlement_structure_type_of_labor_market_region')]

# %% [markdown]
# ### Ridge

# %%
rr = Ridge(alpha=0.5) 
rr.fit(X, Y)
# Out:
# /Users/amitsasson/venv/DSSGx/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=6.95493e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# Ridge(alpha=0.5)

# %%
stats.summary(rr, X, Y, X.columns)
# Out:
# Residuals:
#    Min      1Q  Median     3Q    Max
# -0.612 -0.1245 -0.0228 0.1282 0.6891
#
#
# Coefficients:
#                                                    Estimate                  Std. Error          t value   p value
# _intercept                                       -11.253235  2.347492e+05+1.100000e-05j  -0.0000+0.0000j  0.999962
# supermarkets_population                            0.007800  6.157000e-03+0.000000e+00j   1.2668-0.0000j  0.205972
# supermarkets_average_distance                      0.000106  2.550000e-03+0.000000e+00j   0.0414-0.0000j  0.966980
# public_transport_availability                      0.000330  2.537000e-03-0.000000e+00j   0.1300+0.0000j  0.896633
# average_distance_bus_stop                          0.000254  1.900000e-04+1.000000e-06j   1.3353-0.0077j  0.182521
# average_distance_train_station                     0.000010  2.100000e-05+4.000000e-06j   0.4597-0.0897j  0.639745
# average_distance_public_transport                 -0.000287  2.710000e-04+1.000000e-06j  -1.0595+0.0025j  0.290023
# number_of_students                                 0.000023 -2.000000e-06+0.000000e+00j -11.2479-1.8617j  0.000000
# number_of_hospitals                               -0.018417  4.551000e-03+0.000000e+00j  -4.0471+0.0000j  0.000062
# number_of_hospital_beds                           -0.000150  1.130000e-04-0.000000e+00j  -1.3282-0.0003j  0.184859
# number_of_hospital_beds_adj                        0.016511  4.192000e-03+0.000000e+00j   3.9391-0.0000j  0.000096
# hospital_patiants                                 -0.000004  3.000000e-06+0.000000e+00j  -1.5961+0.1200j  0.110266
# households_of_1_person                             0.000029  1.500000e-05+0.000000e+00j   1.8782-0.0376j  0.061030
# households_of_2_person                             0.000027  2.500000e-05+0.000000e+00j   1.0680-0.0048j  0.286165
# households_of_3_person                             0.000134  5.600000e-05+0.000000e+00j   2.3813-0.0086j  0.017718
# households_of_4_person                             0.000123  1.040000e-04-0.000000e+00j   1.1753+0.0006j  0.240564
# households_of_5_person_or_more                     0.000044  2.230000e-04+0.000000e+00j   0.1976-0.0001j  0.843485
# household_with_kids                               -0.000293  4.500000e-05-0.000000e+00j  -6.5409-0.0296j  0.000000
# household_with_kids_under_3                        0.000281  2.830000e-04-0.000000e+00j   0.9928+0.0002j  0.321387
# household_with_kids_over_3_under_6                -0.000184  3.620000e-04+0.000000e+00j  -0.5085+0.0000j  0.611382
# household_with_kids_over_6_under_10                0.000570  2.100000e-04-0.000000e+00j   2.7100+0.0009j  0.007017
# household_with_kids_over_10_under_15               0.000146  8.100000e-05+0.000000e+00j   1.7992-0.0019j  0.072734
# household_with_kids_over_15_under_18               0.000632  2.080000e-04-0.000000e+00j   3.0386+0.0001j  0.002532
# household_with_double_income_no_kids               0.000089  2.900000e-05-0.000000e+00j   3.0661+0.0041j  0.002316
# car_density                                       -0.000540  6.350000e-04+0.000000e+00j  -0.8496+0.0000j  0.396061
# no_of_paths_per_person_and_day                    -0.023997  2.176117e+00+2.000000e-06j  -0.0110+0.0000j  0.991207
# kilometers_per_person_and_day                      0.053783  3.289700e-02+0.000000e+00j   1.6349-0.0000j  0.102858
# _percentage_out_of_home                            0.052263  1.969200e-02+0.000000e+00j   2.6541-0.0000j  0.008270
# share_of_journeys_on_foot                          0.051797  5.075600e-02-0.000000e+00j   1.0205+0.0000j  0.308095
# ags2_09                                           -0.088943  2.109210e-01-0.000000e+00j  -0.4217-0.0000j  0.673479
# ags2_10                                            0.195530  2.368920e-01+0.000000e+00j   0.8254-0.0000j  0.409637
# ags2_11                                           -0.014386  4.338563e+06+1.920000e-04j  -0.0000+0.0000j  1.000000
# ags2_12                                           -0.043320  2.823015e+05+5.000000e-06j  -0.0000+0.0000j  1.000000
# ags2_13                                           -0.032140  2.824904e+05-7.000000e-06j  -0.0000-0.0000j  1.000000
# ags2_14                                            0.100532  2.823184e+05+1.200000e-05j   0.0000-0.0000j  1.000000
# ags2_15                                            0.051246  2.824621e+05+0.000000e+00j   0.0000-0.0000j  1.000000
# ags2_16                                           -0.066574  2.824374e+05+1.000000e-05j  -0.0000+0.0000j  1.000000
# cluster_1                                         -0.063237  3.840003e+06-6.300000e-05j  -0.0000-0.0000j  1.000000
# cluster_2                                          0.138786  6.537500e-02+0.000000e+00j   2.1229-0.0000j  0.034374
# urban_/_rural_2                                   -0.010786  6.059200e-02+0.000000e+00j  -0.1780+0.0000j  0.858811
# east_west_2                                       -0.004640  2.822526e+05+2.000000e-06j  -0.0000+0.0000j  1.000000
# support_area_status_C*                             0.009291  1.692800e-01+0.000000e+00j   0.0549-0.0000j  0.956256
# support_area_status_C**                            0.242657  2.528580e-01+0.000000e+00j   0.9597-0.0000j  0.337808
# support_area_status_C/D                           -0.045508  2.368040e-01+0.000000e+00j  -0.1922+0.0000j  0.847701
# support_area_status_C/N                            0.088044  4.040990e-01+0.000000e+00j   0.2179-0.0000j  0.827636
# support_area_status_D                              0.005693  5.075880e-01+0.000000e+00j   0.0112-0.0000j  0.991057
# support_area_status_D/N                           -0.053484  7.075370e-01+0.000000e+00j  -0.0756+0.0000j  0.939782
# support_area_status_N                              0.005649  2.346792e+05-4.700000e-05j   0.0000+0.0000j  1.000000
# eligible_area_1                                   -0.005649  2.347122e+05+3.200000e-05j  -0.0000+0.0000j  1.000000
# ---
# R-squared:  0.73113,    Adjusted R-squared:  0.47020
# F-statistic: 2.80 on 197 features

# %% [markdown]
# household_with_kids
# public_transport_per_1000_inhabitants
# number_of_companies_repair_motor_vehicles
# number_of_companies_hospitality
# number_of_companies_technical_services
# debtor_quota
# purchasing_power_per_household

# %% [markdown]
# ## Look at the variables that are important for predicting the error

# %%
g = sns.scatterplot(data=df_mixed, x="Number_of_Commuters_on_place_of_residence)", y="error",  hue="ags5")
g.legend_.remove()

# %%
g = sns.scatterplot(data=df_mixed, x="debtor_quota", y="error",  hue="ags5")
g.legend_.remove()

# %%
sns.kdeplot(data=df_mixed, x="debtor_quota", common_norm=False)
# Out:
# <AxesSubplot:xlabel='debtor_quota', ylabel='Density'>

# %%
g = sns.scatterplot(data=df_mixed, x="purchasing_power_per_household", y="error",  hue="ags5")
g.legend_.remove()

# %%
sns.kdeplot(data=df_mixed, x="purchasing_power_per_household", common_norm=False)
# Out:
# <AxesSubplot:xlabel='purchasing_power_per_household', ylabel='Density'>

# %%
g = sns.scatterplot(data=df_mixed, x="moor_area_percentage", y="error",  hue="ags5")
g.legend_.remove()
