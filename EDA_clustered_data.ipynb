# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

from pathlib import Path
from functools import reduce

# %%
df = pd.read_csv('./corona_data_sets_modified/df_final_with_clusters.csv') 
df
# Out:
#      Unnamed: 0  data_index  cluster   ags5  ags2  \
# 0             0           0        0   1001     1
# 1             1           1        0   1002     1
# 2             2           2        0   1003     1
# 3             3           3        0   1004     1
# 4             4           4        0  10041    10
# ..          ...         ...      ...    ...   ...
# 396         396         396        0   9776     9
# 397         397         397        2   9777     9
# 398         398         398        0   9778     9
# 399         399         399        0   9779     9
# 400         400         400        2   9780     9
#
#                            kreis  supermarkets_population  \
# 0               Flensburg, Stadt                       92
# 1         Kiel, Landeshauptstadt                       92
# 2             Lübeck, Hansestadt                       90
# 3              Neumünster, Stadt                       85
# 4    Regionalverband Saarbrücken                       76
# ...

# %%
df = df.query("cluster != 1")

# %%
sns.histplot(data=df, x="supermarkets_population", hue="cluster",  stat="density", common_norm=False, kde=True)
# Out:
# <AxesSubplot:xlabel='supermarkets_population', ylabel='Density'>

# %%
sns.histplot(data=df, x="median_income", hue="cluster",  stat="density", common_norm=False, kde=True)
# Out:
# <AxesSubplot:xlabel='median_income', ylabel='Density'>

# %%
sns.histplot(data=df, x="household_in_income_calss_6", hue="cluster",  stat="density", common_norm=False, kde=True)
# Out:
# <AxesSubplot:xlabel='household_in_income_calss_6', ylabel='Density'>

# %%
sns.histplot(data=df, x="household_with_kids", hue="cluster",  stat="density", common_norm=False, kde=True)
# Out:
# <AxesSubplot:xlabel='household_with_kids', ylabel='Density'>

# %%
sns.histplot(data=df, x="car_density", hue="cluster",  stat="density", common_norm=False, kde=True)
# Out:
# <AxesSubplot:xlabel='car_density', ylabel='Density'>

# %%
sns.histplot(data=df, x="Proportion_of_in_commuters", hue="cluster",  stat="density", common_norm=False, kde=True)
# Out:
# <AxesSubplot:xlabel='Proportion_of_in_commuters', ylabel='Density'>

# %%
sns.histplot(data=df, x="no_of_births_in_2018", hue="cluster",  stat="density", common_norm=False, kde=True)
# Out:
# <AxesSubplot:xlabel='no_of_births_in_2018', ylabel='Density'>

# %%
sns.histplot(data=df, x="no_of_foreigners_2018", hue="cluster",  stat="density", common_norm=False, kde=True)
# Out:
# <AxesSubplot:xlabel='no_of_foreigners_2018', ylabel='Density'>

# %%
sns.histplot(data=df, x="2019_population", hue="cluster",  stat="density", common_norm=False, kde=True)
# Out:
# <AxesSubplot:xlabel='2019_population', ylabel='Density'>

# %%
sns.histplot(data=df, x="number_of_guests", hue="cluster",  stat="density", common_norm=False, kde=True)
# Out:
# <AxesSubplot:xlabel='number_of_guests', ylabel='Density'>

# %%
sns.histplot(data=df, x="number_of_students", hue="cluster",  stat="density", common_norm=False, kde=True)
# Out:
# <AxesSubplot:xlabel='number_of_students', ylabel='Density'>

# %%
print(', '.join(df.columns.to_numpy()))
# Out:
# Unnamed: 0, data_index, cluster, ags5, ags2, kreis, supermarkets_population, supermarkets_average_distance, public_transport_availability, average_distance_bus_stop, average_distance_train_station, average_distance_public_transport, Unnamed:_0, number_of_students, number_of_hospitals, number_of_hospital_beds, number_of_hospital_beds_adj, hospital_patiants, households_of_1_person, households_of_2_person, households_of_3_person, households_of_4_person, households_of_5_person_or_more, household_with_kids, household_with_kids_under_3, household_with_kids_over_3_under_6, household_with_kids_over_6_under_10, household_with_kids_over_10_under_15, household_with_kids_over_15_under_18, household_with_double_income_no_kids, car_density, no_of_paths_per_person_and_day, kilometers_per_person_and_day, _percentage_out_of_home, share_of_journeys_on_foot, share_of_journeys_on_bike, proportion_of_motorised_vehicle_passenger, share_of_motorised_vehicle_driver, share_of_public_transport_, public_transp
# ...
