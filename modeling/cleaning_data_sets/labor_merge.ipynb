# %%
import pandas as pd
import datetime

# %%
Bestand_SteA_long = pd.read_csv('Bestand_SteA_long.csv', index_col=0)
AST_long = pd.read_csv('AST_long.csv', index_col=0)
SvB_AO_long = pd.read_csv('SvB_AO_long.csv', index_col=0)
SvB_WO_long = pd.read_csv('SvB_WO_long.csv', index_col=0)

# %% [markdown]
# ## merge

# %%
df_final_wide = pd.read_csv('../../final_dfs/for_modeling/df_final_date_wide_2007.csv', index_col=0)
df_final_long = pd.read_csv('../../final_dfs/for_modeling/df_final_date_long_2007.csv', index_col=0)

# %%
#set(df_final_long['variable'])

# %%
# fix date to first day of the month to merge
def fix_day(date):
    return date.replace(day=1)

# %% [markdown]
# ### wide

# %%
df_final_wide.shape
# Out:
# (67368, 40)

# %%
def wide_merge(df_wide, df_final_wide, varname):
    df_wide['datetime'] = pd.to_datetime(df_wide['time_stamp'], format='%Y-%m-%d')
    df_wide['date'] = df_wide['datetime'].apply(fix_day)
    df_wide = df_wide[['ags5', 'date', 'value']]
    df_wide = df_wide.rename(columns={'value': varname})
    df_final_wide['date'] = pd.to_datetime(df_final_wide['date'])
    #df_final_wide = df_final_wide.drop(columns=[f'{varname}'])
    df_final_wide = pd.merge(df_final_wide, df_wide, on=['ags5', 'date'])
    return df_final_wide

# %%
df_final_wide = wide_merge(Bestand_SteA_long, df_final_wide, 'registerd_jobs')
df_final_wide = wide_merge(AST_long, df_final_wide, 'unemployed')
df_final_wide = wide_merge(SvB_AO_long, df_final_wide, 'employees_social_security_at_work')
df_final_wide = wide_merge(SvB_WO_long, df_final_wide, 'employees_social_security_at_residence')

# %%
df_final_wide.shape
# Out:
# (65363, 40)

# %%
df_final_wide=df_final_wide.loc[:, ['ags2', 'ags5','date']]

# %%
wide_merge(Bestand_SteA_long, df_final_wide, 'Bestand_SteA_long')
# Out:
#        ags2   ags5       date  Bestand_SteA_long
# 0         1   1001 2007-05-01                784
# 1         1   1001 2007-06-01                932
# 2         1   1001 2007-07-01                862
# 3         1   1001 2007-08-01                819
# 4         1   1001 2007-09-01                725
# ...     ...    ...        ...                ...
# 65358    16  16077 2020-07-01                664
# 65359    16  16077 2020-08-01                692
# 65360    16  16077 2020-09-01                806
# 65361    16  16077 2020-10-01                774
# 65362    16  16077 2020-11-01                695
#
# [65363 rows x 4 columns]

# %% [markdown]
# ### long

# %%
df_final_long.shape
# Out:
# (599980, 5)

# %%
def long_merge(df_long, df_final_long, varname):
    df_final_long['date'] = pd.to_datetime(df_final_long['date'])
    df_final_long = df_final_long[df_final_long['variable']!=varname]
    df_long['ags2'] = df_long['ags5'].astype(str).str[:-3]
    df_long.rename(columns={f'{varname}': "value"}, inplace=True)
    df_long['variable'] = f'{varname}'
    df_long = df_long[['ags2', 'ags5', 'variable', 'date', 'value']]
    df_final_long = pd.concat([df_final_long, df_long], ignore_index=True)
    return df_final_long

# %%
df_final_long = long_merge(Bestand_SteA_long, df_final_long, 'registerd_jobs')
df_final_long = long_merge(AST_long, df_final_long, 'unemployed')
df_final_long = long_merge(SvB_AO_long, df_final_long, 'employees_social_security_at_work')
df_final_long = long_merge(SvB_WO_long, df_final_long, 'employees_social_security_at_residence')

# %%
df_final_long.shape
# Out:
# (855016, 5)

# %%
# df_final_wide.to_csv('../../final_dfs/for_modeling/df_final_date_wide_2007.csv')
# df_final_long.to_csv('../../final_dfs/for_modeling/df_final_date_long_2007.csv')

# %%
df_final_wide
# Out:
#        ags2   ags5        date  number_of_company_deletions  \
# 0         1   1001  2007-05-01                          4.0
# 1         1   1001  2007-06-01                          8.0
# 2         1   1001  2007-07-01                          9.0
# 3         1   1001  2007-08-01                          6.0
# 4         1   1001  2007-09-01                         11.0
# ...     ...    ...         ...                          ...
# 65358    16  16077  2020-07-01                          2.0
# 65359    16  16077  2020-08-01                          1.0
# 65360    16  16077  2020-09-01                          1.0
# 65361    16  16077  2020-10-01                          0.0
# 65362    16  16077  2020-11-01                          3.0
#
#        number_of_company_liquidations  number_of_start_ups  \
# 0                                 2.0                 21.0
# 1                                 6.0                 18.0
# 2                                 0.0                 18.0
# 3                                 4.0                 10.0
# 4                                 4.0                  6.0
# ...                               ...                  ...
# 65358                             1.0                  5.0
# 65359                             1.0                  4.0
# 65360                             0.0                  5.0
# 65361                             0.0                  7.0
# 65362                             1.0                  5.0
#
#        number_of_companies_administration  number_of_companies_agriculture  \
# 0                                     NaN                              NaN
# 1                                     NaN                              NaN
# 2                                     NaN                              NaN
# 3                                     NaN                              NaN
# 4                                     NaN                              NaN
# ...                                   ...                              ...
# 65358                               114.0                            100.0
# 65359                               114.0                            100.0
# 65360                               114.0                            100.0
# 65361                               114.0                            100.0
# 65362                               114.0                            101.0
#
#        number_of_companies_arts_entertainment  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 65358                                   122.0
# 65359                                   121.0
# 65360                                   121.0
# 65361                                   121.0
# 65362                                   123.0
#
#        number_of_companies_communication  ...  \
# 0                                    NaN  ...
# 1                                    NaN  ...
# 2                                    NaN  ...
# 3                                    NaN  ...
# 4                                    NaN  ...
# ...                                  ...  ...
# 65358                               44.0  ...
# 65359                               44.0  ...
# 65360                               44.0  ...
# 65361                               44.0  ...
# 65362                               45.0  ...
#
#        realized_short_time_work_companies  realized_short_time_work_people  \
# 0                                     NaN                              NaN
# 1                                     NaN                              NaN
# 2                                     NaN                              NaN
# 3                                     NaN                              NaN
# 4                                     NaN                              NaN
# ...                                   ...                              ...
# 65358                               311.0                           2709.0
# 65359                               264.0                           2104.0
# 65360                               224.0                           1750.0
# 65361                               210.0                           1553.0
# 65362                                 NaN                              NaN
#
#        underemployment_without_short_time _work  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 65358                                    4505.0
# 65359                                    4432.0
# 65360                                    4277.0
# 65361                                    4193.0
# 65362                                    4165.0
#
#        unemployment_benefit_entitled  unemployment_benefit_recipients  \
# 0                                NaN                              NaN
# 1                                NaN                              NaN
# 2                                NaN                              NaN
# 3                                NaN                              NaN
# 4                                NaN                              NaN
# ...                              ...                              ...
# 65358                         6661.0                           1022.0
# 65359                         6653.0                           1024.0
# 65360                         6473.0                            970.0
# 65361                         6326.0                            946.0
# 65362                         6225.0                            957.0
#
#        unemployment_rate  registerd_jobs  unemployed  \
# 0                   12.7             784        5559
# 1                   12.2             932        5323
# 2                   12.5             862        5454
# 3                   12.3             819        5377
# 4                   11.7             725        5132
# ...                  ...             ...         ...
# 65358                7.2             664        3242
# 65359                7.3             692        3271
# 65360                7.0             806        3129
# 65361                6.8             774        3050
# 65362                6.8             695        3027
#
#        employees_social_security_at_work  \
# 0                                  38319
# 1                                  38266
# 2                                  38237
# 3                                  38833
# 4                                  38840
# ...                                  ...
# 65358                              27356
# 65359                              27490
# 65360                              27765
# 65361                              27866
# 65362                              27893
#
#        employees_social_security_at_residence
# 0                                       24519
# 1                                       24560
# 2                                       24561
# 3                                       24936
# 4                                       25072
# ...                                       ...
# 65358                                   33148
# 65359                                   33287
# 65360                                   33583
# 65361                                   33603
# 65362                                   33623
#
# [65363 rows x 40 columns]

# %%
df_final_wide.isnull().sum()
# Out:
# ags2                                                  0
# ags5                                                  0
# date                                                  0
# number_of_company_deletions                           0
# number_of_company_liquidations                        0
# number_of_start_ups                                   0
# number_of_companies_administration                56140
# number_of_companies_agriculture                   56140
# number_of_companies_arts_entertainment            56140
# number_of_companies_communication                 56140
# number_of_companies_construction                  56140
# number_of_companies_domestic_staff                56140
# number_of_companies_economic_services             56140
# number_of_companies_education                     56140
# number_of_companies_energy                        56140
# number_of_companies_extraterritorial              56140
# number_of_companies_financial_and_insurance       56140
# number_of_companies_health_and_social_services    56140
# number_of_companies_hospitality                   56140
# number_of_companies_manufacturing                 56140
# number_of_companies_mining                        56140
# number_of_companies_real_estat                    56140
# number_of_companies_rendering_other_services      56140
# number_of_companies_repair_motor_vehicles         56140
# number_of_companies_technical_services            56140
# number_of_companies_transport                     56140
# number_of_companies_unknown_sector                56140
# number_of_companies_water_and_sewage              56140
# displayed_short_time_work_companies               60952
# displayed_short_time_work_people                  60952
# realized_short_time_work_companies                61353
# realized_short_time_work_people                   61353
# underemployment_without_short_time _work          56140
# unemployment_benefit_entitled                     56541
# unemployment_benefit_recipients                   56140
# unemployment_rate                                     0
# registerd_jobs                                        0
# unemployed                                            0
# employees_social_security_at_work                     0
# employees_social_security_at_residence                0
# dtype: int64
