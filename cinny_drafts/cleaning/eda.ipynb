# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_final_wide = pd.read_csv('../../final_dfs/for_modeling/df_final_date_wide_2007.csv', index_col=0)
df_final_long = pd.read_csv('../../final_dfs/for_modeling/df_final_date_long_2007.csv', index_col=0)

# %%
df_final_wide['ags5']
# Out:
# 0         1001
# 1         1001
# 2         1001
# 3         1001
# 4         1001
#          ...
# 65358    16077
# 65359    16077
# 65360    16077
# 65361    16077
# 65362    16077
# Name: ags5, Length: 65363, dtype: int64

# %%
plt.figure(figsize=(40,20))
plt.plot(df_final_wide[(df_final_wide['ags5']==1001)]['date'],
         df_final_wide[(df_final_wide['ags5']==1001)]['unemployment_rate'])
plt.xticks(rotation=60)
plt.show()
